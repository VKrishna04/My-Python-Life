# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %% [markdown]
# # Distributions

# %% [markdown]
# ## Binomial

# %%
sum(np.random.binomial(12, 0.2, 20000) != 4) / 20000.0
# Out:
# 0.86875

# %%
sum(np.random.binomial(9, 0.1, 20000) == 0) / 20000.0
# Out:
# 0.38625

# %% [markdown]
# ## Poisson

# %%
sum(np.random.poisson(12, 10000) >= 17) / 10000
# Out:
# 0.0994

# %% [markdown]
# ## Uniform

# %%
sum(np.random.uniform(0, 20, 1000) > 5) / 1000
# Out:
# 0.75

# %%
sum(np.random.uniform(0, 20, 1000) < 10) / 1000
# Out:
# 0.494

# %%
(sum(np.random.uniform(0, 20, 1000) > 5) / 1000) - (
    sum(np.random.uniform(0, 20, 1000) < 10) / 1000
)
# Out:
# 0.239

# %%
s = np.random.uniform(-1, 0, 1000)
np.all(s >= 0)
np.all(s < 20)
# Out:
# True

# %% [markdown]
# ## Normal

# %%
mu, sigma = 10, 2  # mean and standard deviation
sum(np.random.normal(mu, sigma, 1000) > 13) / 1000
# Out:
# 0.082

# %%
s = np.random.normal(mu, sigma, 1000)

# %%
plt.style.use('fivethirtyeight')
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
linewidth=2, color='r')
plt.show()

# %% [markdown]
# ## Exponential

# %%
sum(np.random.exponential(scale=1/4, size=1000) < 0.5) / 1000
# Out:
# 0.859

# %%
sum(np.random.exponential(scale=1.4, size=1000)) / 1000.0
# Out:
# 1.3820417873146429

# %%
import math

x = -(8 / 12)
1 - math.exp(x)
# Out:
# 0.486582880967408

# %% [markdown]
# # Descriptive Statistics

# %%
d1 = pd.read_csv(r'../Datasets/uk-500.csv')
d1.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web
# 0  http://www.alandrosenburgcpapc.co.uk
# 1     http://www.capgeminiamerica.co.uk
# 2      http://www.elliottjohnwesq.co.uk
# 3          http://www.mcmahanbenl.co.uk
# 4        http://www.champagneroom.co.uk

# %% [markdown]
# Population Sampling

# %%
d1.sample(n=3)
# Out:
#     first_name   last_name                company_name         address  \
# 360    Rebbeca  Rubinstein          Cullen, Jack J Esq   4 Sherwood St
# 293     Adelle   Schantini    Creative Photography Inc  162 Grayson St
# 463       Cora     Mossing  Regis Brd Pro Engrs & Land   38 Raffles St
#
#                    city          county   postal        phone1        phone2  \
# 360  Speke-Garston Ward      Merseyside  L24 6SH  01708-724957  01862-469721
# 293     Greenlands Ward      Lancashire  FY2 0TD  01624-595660  01938-262356
# 463           Newmarket  Cambridgeshire  CB8 8QE  01285-381062  01699-194090
#
#                               email                                      web
# 360  rebbeca_rubinstein@hotmail.com          http://www.cullenjackjesq.co.uk
# 293      adelle_schantini@yahoo.com  http://www.creativephotographyinc.co.uk
# 463                  cora@yahoo.com    http://www.regisbrdproengrsland.co.uk

# %%
d1.sample(frac=0.1)
# Out:
#     first_name   last_name                    company_name  \
# 317   Precious     Brabble            Sigmacom Corporation
# 194    Orville       Zuehl               Teti, Louis N Esq
# 161    Phillip        Aloi             Duffield, Michael C
# 373    Chantay       Jirsa                   Posey Company
# 481      Ahmad     Alsaqri    Alliance Construction Co Inc
# 25     Leonard      Kufner    Arctic Star Distributing Inc
# 124  Celestina       Pince          Mcallister & Murphy Pc
# 57     Justine       Salta      Barajas & Bustamante Archl
# 236    Therese     Shiraki                     Wuhf Fox 31
# 6         Marg    Grasmick   Wrangle Hill Auto Auct & Slvg
# 173     Freida     Newyear        Flash, Elena Salerno Esq
# 377     Theron     Merriam            Percival, Mark R Esq
# 395       Lyda    Cronholm                      Print Shop
# 79     Bettina        Kham     Council Of Cmnty Blood Ctrs
# 337    Joaquin       Hysom                    Sport Toyota
# 489   Krystina  Schlabaugh           Harris Oldsmobile Inc
# 214     Leigha     Semenza                    Unique Epoxy
# 271  Veronique    Nuckolls       Cinemax Cable Pay Tv Svce
# 367   Laquanda         Kho         Bayou Welding Works Inc
# 456       Viki    Humeniuk      Guldstrand Engineering Inc
# 357      Beula       Lingo                  Bauer Coatings
# 37     Vernice    Sperazza            Novak, Alan Paul Esq
# 306      Denny   Casalenda         Ringo International Inc
# 375      Alton       Rampy         Reliable Metalcraft Inc
# 387    Destiny      Madlem                    Diesel Recon
# 148    Janella    Altobell             Shannon, Paul V Esq
# 275        Eve    Hoffstot    Domestic Intrntl Techlgy Ltd
# 315      Jacki    Sterback             Praver, David L Esq
# 455     Quiana   Scarsella                    Looking Good
# 220       Chan      Loftin             Hydrick Law Offices
# 383    Emogene   Ritthaler        Mcdonald Service Station
# 9       Yuette      Klapec                       Max Video
# 388     Gaston     Szumski             Red Giant Foods Inc
# 267      Laura      Gumaer               C Leasing Company
# 93      Monroe      Damato              Rosati, Marc D Esq
# 210     Pearly         Ero                     Rug Gallery
# 410       Dong     Oropeza             Mayo, Timothy L Esq
# 67     Stefany      Ferenz              L & L Sales Co Inc
# 392  Magdalene   Cocherell          Southern Interiors Inc
# 242      Melda  Colamarino         Proctor & Associates Co
# 346       Nina      Yaklin                 Ramm Metals Inc
# 188      Timmy     Lintner  Interdependence Associates Inc
# 364      Billy       Selma                      Taylor Inn
# 135      Emily    Pogorelc     Mccartney Printing Services
# 223   Chantell      Besong                   Kelly, Mark C
# 440    Lovetta       Study         Borton Petrini & Conron
# 210                    http://www.ruggallery.co.uk
# 410               http://www.mayotimothylesq.co.uk
# 67                   http://www.llsalescoinc.co.uk
# 392          http://www.southerninteriorsinc.co.uk
# 242           http://www.proctorassociatesco.co.uk
# 346                 http://www.rammmetalsinc.co.uk
# 188  http://www.interdependenceassociatesinc.co.uk
# 364                     http://www.taylorinn.co.uk
# 135     http://www.mccartneyprintingservices.co.uk
# 223                    http://www.kellymarkc.co.uk
# 440           http://www.bortonpetriniconron.co.uk
# 358          http://www.wordimageworkshopinc.co.uk
# 186                  http://www.mailboxesetc.co.uk
# 307            http://www.dorvaltradingcoltd.co.uk
# 281               http://www.shohetgracecesq.co.uk

# %%
d1.sample(n=3, replace=True)
# Out:
#     first_name last_name                 company_name         address  \
# 413     Shelia     Plues          Schen, Sanford E Md  9730 Dunnet St
# 135      Emily  Pogorelc  Mccartney Printing Services    5196 York St
# 427    Antonio    Heilig         Radisson Suite Hotel  35 Elton St #3
#
#                   city   county    postal        phone1        phone2  \
# 413  Silloth-on-Solway  Cumbria   CA7 4RB  01818-260618  01574-927461
# 135        Orsett Ward    Essex  SS17 8NS  01416-913482  01439-493163
# 427           Ipplepen    Devon  TQ12 5LL  01324-171614  01442-946357
#
#                         email                                         web
# 413          shelia@gmail.com            http://www.schensanfordemd.co.uk
# 135  emily.pogorelc@yahoo.com  http://www.mccartneyprintingservices.co.uk
# 427  antonio.heilig@gmail.com         http://www.radissonsuitehotel.co.uk

# %%
d1.sample(n=3, random_state=1)
# Out:
#     first_name   last_name          company_name           address  \
# 304   Remedios  Arlinghaus  Miller, Martin M Esq  9 Duckenfield St
# 340    Shannon   Kobayashi                 Hungs  1111 Nesfield St
# 47       Luisa    Devereux         Cash 4 Checks  3 North View #35
#
#                                city                 county    postal  \
# 304                       Aldbrough  E Riding of Yorkshire  HU11 4QA
# 340      Tonge with the Haulgh Ward     Greater Manchester   BL2 2SU
# 47   Burmantofts and Richmond Hill          West Yorkshire   LS9 7JH
#
#            phone1        phone2                          email  \
# 304  01536-498792  01883-435283  remedios.arlinghaus@gmail.com
# 340  01620-435994  01436-122588              shannon@yahoo.com
# 47   01607-269930  01334-807355            ldevereux@gmail.com
#
#                                    web
# 304  http://www.millermartinmesq.co.uk
# 340             http://www.hungs.co.uk
# 47         http://www.cashchecks.co.uk

# %%
d1.sample(frac=0.10, replace=True, random_state=5)
# Out:
#      first_name   last_name                    company_name  \
# 355     Margery       Rohrs   C G Mccullough Insurance Agcy
# 206     Ashanti        Donn                      Denticator
# 495       Avery        Veit      Plaza Gourmet Delicatessen
# 189        Zita      Speltz                Mmm Design Group
# 486      Sophia     Gaucher               T C E Systems Inc
# 118       Paola       Dease        Sunderland Publishing Co
# 400      Leeann       Flory  Fleetwood Area School District
# 73          Yun     Paletta              Goe, Douglas E Esq
# 8          Lura    Manzella                 Bizerba Usa Inc
# 228     Dominic    Washmuth            Bremer, Duncan S Esq
# 231      Bonita    Sandblom             Transbay Steel Corp
# 446         Ona     Bowhall              Cohen And Fromm Pc
# 348           Llwyn-y-Pia Community  Rhondda Cynon Taff  CF40 2JJ
# 270  Neilston, Uplawmoor and Newton   East Renfrewshire   G78 3AB
# 106              Woodhall Farm Ward       Hertfordshire   HP2 7JP
#
#            phone1        phone2                       email  \
# 102  01860-191930  01409-786106         gstanwick@gmail.com
# 435  01997-409950  01722-935404  dudley_dibartolo@yahoo.com
# 348  01550-463222  01567-215689      jacob.kippel@yahoo.com
# 270  01295-844061  01796-315694         charlie@isita.co.uk
# 106  01413-348876  01659-621050           shawana@yahoo.com
#
#                                             web
# 102  http://www.tiburonpenchmbrcommrceinc.co.uk
# 435         http://www.mcknighthvincentjr.co.uk
# 348           http://www.accautomationinc.co.uk
# 270           http://www.sotorrioreneaesq.co.uk
# 106    http://www.bestwesternriverviewinn.co.uk

# %% [markdown]
# Stratified Sampling

# %%
d2 = pd.read_csv(r'../Datasets/StudentsPerformance.csv')
d2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.histplot(d2['race/ethnicity'])
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='Count'>

# %%
d2.groupby('race/ethnicity', group_keys=False).apply(lambda x:x.sample(min(len(x),3)))
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_20288\2903035930.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   d2.groupby('race/ethnicity', group_keys=False).apply(lambda x:x.sample(min(len(x),3)))
#      gender race/ethnicity parental level of education         lunch  \
# 575    male        group A          associate's degree  free/reduced
# 589  female        group A            some high school      standard
# 623    male        group A                some college      standard
# 126    male        group B            some high school      standard
# 396  female        group B                 high school  free/reduced
# 655  female        group B                some college      standard
# 542  female        group C          associate's degree      standard
# 663  female        group C                 high school      standard
# 95     male        group C          associate's degree  free/reduced
# 66     male        group D            some high school  free/reduced
# 87   female        group D          associate's degree      standard
# 106  female        group D             master's degree      standard
# 458  female        group E           bachelor's degree      standard
# 233    male        group E            some high school      standard
# 60     male        group E           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 575               completed          40             55             53
# 589                    none          48             66             65
# 623               completed         100             96             86
# 126                    none          72             68             67
# 396                    none          50             67             63
# 655                    none          62             67             67
# 542                    none          81             77             79
# 663                    none          65             69             67
# 95                completed          78             81             82
# 66                     none          45             37             37
# 87                     none          71             71             74
# 106                    none          87            100            100
# 458                    none         100            100            100
# 233                    none          92             87             78
# 60                completed          79             74             72

# %%
d2.groupby('gender', group_keys=False).apply(lambda x:x.sample(min(len(x),3)))
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_20288\2131878601.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   d2.groupby('gender', group_keys=False).apply(lambda x:x.sample(min(len(x),3)))
#      gender race/ethnicity parental level of education         lunch  \
# 582  female        group D           bachelor's degree  free/reduced
# 116  female        group B           bachelor's degree  free/reduced
# 431  female        group C                 high school      standard
# 469    male        group C                some college      standard
# 77     male        group A           bachelor's degree      standard
# 331    male        group C          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 582                    none          63             73             78
# 116                    none          75             85             82
# 431                    none          61             72             70
# 469                    none          91             74             76
# 77                completed          80             78             81
# 331                    none          47             37             35

# %% [markdown]
# Systematic Sampling

# %%
step_size = 6
d2.iloc[::step_size]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 6    female        group B                some college      standard
# 12   female        group B                 high school      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 972  female        group A                 high school  free/reduced
# 978    male        group D                 high school      standard
# 984  female        group C            some high school      standard
# 990    male        group E                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 6                 completed          88             95             92
# 12                     none          65             81             73
# 18                completed          46             42             46
# 24                completed          74             71             80
# ..                      ...         ...            ...            ...
# 972               completed          53             50             60
# 978               completed          55             41             48
# 984                    none          74             75             82
# 990               completed          86             81             75
# 996                    none          62             55             55
#
# [167 rows x 8 columns]

# %%
# Frequency Distribution Range
reading_range = np.amax(d2['reading score'])-np.amin(d2['reading score'])
reading_range
# Number of Classes
num_of_classes=6
# Class Interval
class_interval = reading_range/num_of_classes
class_interval
# Class Midpoint
# Relative Frequency
d2['reading score'].value_counts()
# CUmilative Frequency
d2['reading score'].value_counts().sort_index().cumsum()
# Out:
# reading score
# 17        1
# 23        2
# 24        4
# 26        5
# 28        6
#        ...
# 95      971
# 96      975
# 97      980
# 99      983
# 100    1000
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# ## Measures of Central Tendency

# %% [markdown]
# Mean

# %%
d2['math score'].mean()
# Out:
# 66.089

# %%
d2.mean(axis=0, skipna=True, numeric_only=True)
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %% [markdown]
# Median

# %%
d2['reading score'].median()
# Out:
# 70.0

# %% [markdown]
# Mode

# %%
d2['reading score'].mode()
# Out:
# 0    72
# Name: reading score, dtype: int64

# %% [markdown]
# Percentile

# %%
d2.quantile(.2, axis = 0,numeric_only=True)
# Out:
# math score       53.0
# reading score    57.0
# writing score    54.0
# Name: 0.2, dtype: float64

# %%
d2.quantile([.1, .3, .63, .95], axis = 0,numeric_only=True)
# Out:
#       math score  reading score  writing score
# 0.10       47.00          51.00           48.0
# 0.30       59.00          62.00           60.0
# 0.63       71.00          74.37           74.0
# 0.95       90.05          92.00           92.0

# %% [markdown]
# Quartile

# %%
d2.quantile([.25, .50, .75], axis = 0,numeric_only=True)
# Out:
#       math score  reading score  writing score
# 0.25        57.0           59.0          57.75
# 0.50        66.0           70.0          69.00
# 0.75        77.0           79.0          79.00

# %% [markdown]
# Measures of Variance

# %%
d3 = pd.read_csv(r'../Datasets/nba.csv')
d3.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
d3.skew(axis=0, skipna=True, numeric_only=True)
# Out:
# Number    1.668386
# Age       0.626349
# Weight    0.113788
# Salary    1.576321
# dtype: float64

# %% [markdown]
# Histogram

# %%
d3['Salary'].sort_values().hist().plot(use_index=False)
# Out:
# []

# %% [markdown]
# Box Plot

# %%
sns.boxplot(d3['Salary'])
# Out:
# <Axes: ylabel='Salary'>

# %% [markdown]
# ## Kurtosis

# %%
d3.kurtosis(numeric_only=True)
# Out:
# Number    4.364464
# Age      -0.051119
# Weight   -0.552546
# Salary    1.839177
# dtype: float64
