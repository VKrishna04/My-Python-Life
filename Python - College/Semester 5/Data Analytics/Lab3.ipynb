# %% [markdown]
# # Pandas
# for Data Manipulation, Data Visulisation

# %% [markdown]
# ## Data Structures
# 1. Pandas Series
# 2. Data Frames

# %% [markdown]
# Pandas Series

# %%
import pandas as pd
import numpy as np

# Creating empty series
ser = pd.Series()
display(f"Pandas Series: \n{ser}")

# Simple Array
data = np.array([_ for _ in "geeks"])

# Creating filled series
ser = pd.Series(data)
display(f"Pandas Series: \n{ser}")
# Out:
# 'Pandas Series: \nSeries([], dtype: object)'
# 'Pandas Series: \n0    g\n1    e\n2    e\n3    k\n4    s\ndtype: object'

# %%
import pandas as pd

series = [_ for _ in "CSE"]
ser = pd.Series(series)
display(ser)
# Out:
# 0    C
# 1    S
# 2    E
# dtype: object

# %% [markdown]
# Data Frames

# %%
import pandas as pd

data = {
    "Name": ["Tom", "will", "kill", "pandey"],
    "Age": [
        20,
        21,
        22,
        23,
    ],
}
df = pd.DataFrame(data)
display(df)
# Out:
#      Name  Age
# 0     Tom   20
# 1    will   21
# 2    kill   22
# 3  pandey   23

# %%
import pandas as pd

data = {
    "Name": ["Jai", "Princi", "Gaurav", "Anuj"],
    "Age": [27, 24, 22, 32],
    "Adress": ["Delhi", "Kanpur", "Allahabad", "Kannauj"],
    "Qualification": ["Msc", "MA", "MCA", "Phd"],
}
df = pd.DataFrame(data)
display(df)
display(df[['Name','Qualification']])
# Out:
#      Name  Age     Adress Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('nba.csv')

# Display location
print(df.iloc[0])
print(df.iloc[0:0])

# Display the first 5 rows of the DataFrame
print("Head of the DataFrame:")
display(df.head())

# Display the last 5 rows of the DataFrame
print("\nTail of the DataFrame:")
display(df.tail())

# Display the info of the DataFrame
print("\nInfo of the DataFrame:")
display(df.info())

# Display the descriptive statistics of the DataFrame
print("\nDescription of the DataFrame:")
display(df.describe())
# Out:
# Name         Avery Bradley
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: 0, dtype: object
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []
# Head of the DataFrame:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('nba.csv')

# Display the columns of the DataFrame
print("Columns of the DataFrame:")
display(df.columns)
# Out:
# Columns of the DataFrame:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# full information on `Avery Bradley`

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('nba.csv')

# Filter the DataFrame for Avery Bradley
avery_bradley_info = df[df['Name'] == 'Avery Bradley']

# Display the full information of Avery Bradley
print("Full information on Avery Bradley:")
display(avery_bradley_info)
# Out:
# Full information on Avery Bradley:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %% [markdown]
# sort

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('nba.csv')

# Sort the DataFrame by a specific column
sorted_df = df.sort_values(by=['Age','Weight'])

# Display the sorted DataFrame
display(sorted_df)
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 226     Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0    6-6
# 122      Devin Booker            Phoenix Suns     1.0       SG  19.0    6-6
# 445        Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 116  D'Angelo Russell      Los Angeles Lakers     1.0       PG  20.0    6-5
# 401        Tyus Jones  Minnesota Timberwolves     1.0       PG  20.0    6-2
# ..                ...                     ...     ...      ...   ...    ...
# 261      Vince Carter       Memphis Grizzlies    15.0       SG  39.0    6-6
# 304      Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3
# 400     Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 298        Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
# 457               NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College     Salary
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('nba.csv')

# Display the sorted DataFrame
print(df.loc[2])
# Out:
# Name             John Holland
# Team           Boston Celtics
# Number                   30.0
# Position                   SG
# Age                      27.0
# Height                    6-5
# Weight                  205.0
# College     Boston University
# Salary                    NaN
# Name: 2, dtype: object

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('nba.csv')

# Display the sorted DataFrame
display(df.iloc[0:2])
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('nba.csv')

# Display the sorted DataFrame
print(df.shape)
# Out:
# (458, 9)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('nba.csv')

# Sort the DataFrame by a specific column
sorted_df = df.sort_values(by=['Age','Weight'],na_position='first')

# Display the sorted DataFrame
display(sorted_df)
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 457               NaN                     NaN     NaN      NaN   NaN    NaN
# 226     Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0    6-6
# 122      Devin Booker            Phoenix Suns     1.0       SG  19.0    6-6
# 445        Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 116  D'Angelo Russell      Los Angeles Lakers     1.0       PG  20.0    6-5
# ..                ...                     ...     ...      ...   ...    ...
# 102    Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3
# 261      Vince Carter       Memphis Grizzlies    15.0       SG  39.0    6-6
# 304      Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3
# 400     Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 298        Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
#
#      Weight         College     Salary
# ...
