# %% [markdown]
# Name: Krishna GSVV
# Roll no. AV.EN.U4CSE22016
# Date: 20/8/24

# %%
import pandas as pd
import numpy as np
ser = pd.Series()
print("pandas series:",ser)
data = np.array(['g','e','e','k','s'])
ser =pd.Series(data)
print("pandas series:\n",ser)
# Out:
# pandas series: Series([], dtype: object)
# pandas series:
#  0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
import pandas as pd
import numpy as np
series = ['c','s','e']
ser =pd.Series(series)
print(ser)
# Out:
# 0    c
# 1    s
# 2    e
# dtype: object

# %%
import pandas as pd
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
data=(["name","age"],["harshi","19"],["rishi","19"])
df=pd.DataFrame(data)
print(df)
# Out:
#         0    1
# 0    name  age
# 1  harshi   19
# 2   rishi   19

# %%
import pandas as pd
data={"name":["harshi","rishi"],"Age":[19,19]}
df=pd.DataFrame(data)
print(df)
# Out:
#      name  Age
# 0  harshi   19
# 1   rishi   19

# %%
import pandas as pd
data={"name":["jai","princi","gaurav","anuj"],"Age":[27,24,22,32],"Address":["delhi","kanpur","allhabad","kannaauj"],"Qualification":["msc","ma","mca","phd"]}
df=pd.DataFrame(data)
print(df)
# Out:
#      name  Age   Address Qualification
# 0     jai   27     delhi           msc
# 1  princi   24    kanpur            ma
# 2  gaurav   22  allhabad           mca
# 3    anuj   32  kannaauj           phd

# %%
import pandas as pd
data={"name":["jai","princi","gaurav","anuj"],"Age":[27,24,22,32],"Address":["delhi","kanpur","allhabad","kannaauj"],"Qualification":["msc","ma","mca","phd"]}
df=pd.DataFrame(data)
print(df[["name","Qualification"]])
# Out:
#      name Qualification
# 0     jai           msc
# 1  princi            ma
# 2  gaurav           mca
# 3    anuj           phd

# %%
import pandas as pd
data =pd.read_csv("nba.csv",index_col="Name")
print(data)
data.shape
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
print(data.iloc[0])
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object

# %%
print(data.loc["Avery Bradley"])
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")
first = data.loc["Avery Bradley"]
second = data.loc["R.J. Hunter"]
print(first, "\n\n\n", second)
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object
#
#
#  Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %%
data.sort_values(by="Age")
# Out:
#                                       Team  Number Position   Age Height  \
# Name
# Rashad Vaughn              Milwaukee Bucks    20.0       SG  19.0    6-6
# Devin Booker                  Phoenix Suns     1.0       SG  19.0    6-6
# Kristaps Porzingis         New York Knicks     6.0       PF  20.0    7-3
# Tyus Jones          Minnesota Timberwolves     1.0       PG  20.0    6-2
# Cliff Alexander     Portland Trail Blazers    34.0       PF  20.0    6-8
# ...                                    ...     ...      ...   ...    ...
# Pablo Prigioni        Los Angeles Clippers     9.0       PG  39.0    6-3
# Tim Duncan               San Antonio Spurs    21.0        C  40.0   6-11
# Kevin Garnett       Minnesota Timberwolves    21.0       PF  40.0   6-11
# Andre Miller             San Antonio Spurs    24.0       PG  40.0    6-3
# NaN                                    NaN     NaN      NaN   NaN    NaN
#
#                     Weight      College     Salary
# Name
# ...

# %%
data.sort_values(by="Age",ascending=False)
# Out:
#                                   Team  Number Position   Age Height  Weight  \
# Name
# Andre Miller         San Antonio Spurs    24.0       PG  40.0    6-3   200.0
# Kevin Garnett   Minnesota Timberwolves    21.0       PF  40.0   6-11   240.0
# Tim Duncan           San Antonio Spurs    21.0        C  40.0   6-11   250.0
# Vince Carter         Memphis Grizzlies    15.0       SG  39.0    6-6   220.0
# Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3   185.0
# ...                                ...     ...      ...   ...    ...     ...
# Tyus Jones      Minnesota Timberwolves     1.0       PG  20.0    6-2   195.0
# Christian Wood      Philadelphia 76ers    35.0       PF  20.0   6-11   220.0
# Rashad Vaughn          Milwaukee Bucks    20.0       SG  19.0    6-6   202.0
# Devin Booker              Phoenix Suns     1.0       SG  19.0    6-6   206.0
# NaN                                NaN     NaN      NaN   NaN    NaN     NaN
#
# ...

# %%
data.sort_values(by=["Age","Salary"],ascending=False)
# Out:
#                                    Team  Number Position   Age Height  Weight  \
# Name
# Kevin Garnett    Minnesota Timberwolves    21.0       PF  40.0   6-11   240.0
# Tim Duncan            San Antonio Spurs    21.0        C  40.0   6-11   250.0
# Andre Miller          San Antonio Spurs    24.0       PG  40.0    6-3   200.0
# Vince Carter          Memphis Grizzlies    15.0       SG  39.0    6-6   220.0
# Pablo Prigioni     Los Angeles Clippers     9.0       PG  39.0    6-3   185.0
# ...                                 ...     ...      ...   ...    ...     ...
# Christian Wood       Philadelphia 76ers    35.0       PF  20.0   6-11   220.0
# Cliff Alexander  Portland Trail Blazers    34.0       PF  20.0    6-8   240.0
# Devin Booker               Phoenix Suns     1.0       SG  19.0    6-6   206.0
# Rashad Vaughn           Milwaukee Bucks    20.0       SG  19.0    6-6   202.0
# NaN                                 NaN     NaN      NaN   NaN    NaN     NaN
#
# ...

# %%
data.sort_values(by=["Age","Salary"],na_position='first')
# Out:
#                                    Team  Number Position   Age Height  Weight  \
# Name
# NaN                                 NaN     NaN      NaN   NaN    NaN     NaN
# Rashad Vaughn           Milwaukee Bucks    20.0       SG  19.0    6-6   202.0
# Devin Booker               Phoenix Suns     1.0       SG  19.0    6-6   206.0
# Christian Wood       Philadelphia 76ers    35.0       PF  20.0   6-11   220.0
# Cliff Alexander  Portland Trail Blazers    34.0       PF  20.0    6-8   240.0
# ...                                 ...     ...      ...   ...    ...     ...
# Pablo Prigioni     Los Angeles Clippers     9.0       PG  39.0    6-3   185.0
# Vince Carter          Memphis Grizzlies    15.0       SG  39.0    6-6   220.0
# Andre Miller          San Antonio Spurs    24.0       PG  40.0    6-3   200.0
# Tim Duncan            San Antonio Spurs    21.0        C  40.0   6-11   250.0
# Kevin Garnett    Minnesota Timberwolves    21.0       PF  40.0   6-11   240.0
#
# ...
